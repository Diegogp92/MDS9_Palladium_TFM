# %%
import pandas as pd
import numpy as np
import pickle

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_colwidth', None)

# %%
df_dropdown = pd.read_csv(r'C:\DEV\TFM\00_TFM_PALLADIUM\06_STREAMLIT\Datos_a_extraer.csv', sep = ';')
df_dropdown.head(15)
# Out:
#                                        HOTEL  LLEGADA_MES  LLEGADA_DIAm  \
# 0                       ComplejoCostaMujeres          1.0           1.0
# 1                          ComplejoPuntaCana          2.0           2.0
# 2                        ComplejoRivieraMaya          3.0           3.0
# 3                DominicanFiestaHotel&Casino          4.0           4.0
# 4           GrandPalladiumImbassaiResort&Spa          5.0           5.0
# 5   GrandPalladiumJamaica&LadyHamiltonResort          6.0           6.0
# 6                          PalladiumVallarta          7.0           7.0
# 7                                 TRSCapCana          8.0           8.0
# 8                                        NaN          9.0           9.0
# 9                                        NaN         10.0          10.0
# 10                                       NaN         11.0          11.0
# 11                                       NaN         12.0          12.0
# 12                                       NaN          NaN          13.0
# 13                                       NaN          NaN          14.0
# 14                                       NaN          NaN          15.0
#
#     LLEGADA_DIAs LLEGADA_AVANCE  SALIDA_MES  SALIDA_DIAm  SALIDA_DIAs  \
# 0            1.0      Calculado         1.0          1.0          1.0
# 1            2.0            NaN         2.0          2.0          2.0
# 2            3.0            NaN         3.0          3.0          3.0
# 3            4.0            NaN         4.0          4.0          4.0
# 4            5.0            NaN         5.0          5.0          5.0
# 5            6.0            NaN         6.0          6.0          6.0
# 6            7.0            NaN         7.0          7.0          7.0
# 7            NaN            NaN         8.0          8.0          NaN
# 8            NaN            NaN         9.0          9.0          NaN
# 9            NaN            NaN        10.0         10.0          NaN
# 10           NaN            NaN        11.0         11.0          NaN
# 11           NaN            NaN        12.0         12.0          NaN
# 12           NaN            NaN         NaN         13.0          NaN
# 13           NaN            NaN         NaN         14.0          NaN
# 14           NaN            NaN         NaN         15.0          NaN
#
#    SALIDA_AVANCE            NOCHES DURACION_ESTANCIA               REGIMEN  \
# 0      Calculado  Calculado y <247      Calculado y:          AllInclusive
# 1            NaN               NaN             Corta  AlojamientoyDesayuno
# 2            NaN               NaN             Larga           Desconocido
# 3            NaN               NaN             Media          MediaPension
# 4            NaN               NaN          MuyLarga       PensionCompleta
# 5            NaN               NaN       SinPernocta       SoloAlojamiento
# 6            NaN               NaN               NaN                   NaN
# 7            NaN               NaN               NaN                   NaN
# 8            NaN               NaN               NaN                   NaN
# 9            NaN               NaN               NaN                   NaN
# 10           NaN               NaN               NaN                   NaN
# 11           NaN               NaN               NaN                   NaN
# 12           NaN               NaN               NaN                   NaN
# 13           NaN               NaN               NaN                   NaN
# 14           NaN               NaN               NaN                   NaN
#
#                      TIPO      USO          PAX_NUM       PAX_CAT  ADULTOS  \
# 0   BAVAmbassadorSuitePOV  int 1-6  Calculado y 1-8  Calculado y:  int 0-8
# 1        BAVJuniorSuiteBS      NaN              NaN      Familias      NaN
# 2        BAVJuniorSuiteGV      NaN              NaN       Parejas      NaN
# 3     BAVJuniorSuiteSWPOV      NaN              NaN        Single      NaN
# 4          BAVPremiumJSGV      NaN              NaN           NaN      NaN
# 5       BAVRomanceSuiteBS      NaN              NaN           NaN      NaN
# 6       BAVRomanceSuiteGV      NaN              NaN           NaN      NaN
# 7          BAVRooftopJTJS      NaN              NaN           NaN      NaN
# 8          BAVRooftopJTST      NaN              NaN           NaN      NaN
# 9    BAVSignatureSuitePOV      NaN              NaN           NaN      NaN
# 10        BAVSuperiorJSBS      NaN              NaN           NaN      NaN
# 11        BAVSuperiorJSGV      NaN              NaN           NaN      NaN
# 12    CAPAmbassadorSTPSOV      NaN              NaN           NaN      NaN
# 13       CAPJuniorSuiteMV      NaN              NaN           NaN      NaN
# 14     CAPJuniorSuitePSOV      NaN              NaN           NaN      NaN
#
#       NENES    BEBES  TIPO_CLIENTE                                CLIENTE  \
# 0   int 0-6  int 0-3           1.0               (Ecomm)CLUBTURAVIASAdeCV
# 1       NaN      NaN           2.0                      (NOUSAR)BADATOURS
# 2       NaN      NaN           9.0  (NOUSAR)GLOBALTRAVELINTERNATIONAL(FL)
# 3       NaN      NaN           NaN           (NOUSAR)RUTAMAYATRAVELSADECV
# 4       NaN      NaN           NaN             (NOUSAR)SARAPETROLETRAVELS
# 5       NaN      NaN           NaN                       360oTOUROPERADOR
# 6       NaN      NaN           NaN                   3D'SLIFESTYLEBOOKING
# 7       NaN      NaN           NaN                 7THHEAVENJAMAICATRAVEL
# 8       NaN      NaN           NaN                              A&BMaster
# 9       NaN      NaN           NaN                        AAAOHIOAUTOCLUB
# 10      NaN      NaN           NaN               AANDB;CARIBEANTRAVEL;LLC
# 11      NaN      NaN           NaN                              AAVTRAVEL
# 12      NaN      NaN           NaN                           ABACOTURISMO
# 13      NaN      NaN           NaN     ABBOTTRAVEL,LOMBARIHOLDINGSLIMITED
# 14      NaN      NaN           NaN                            AbreuOnline
#
#       GRUPO MONEDA SUPLETORIA    CUNAS  FECHA_TOMA_MES  FECHA_TOMA_DIAm  \
# 0   int 0-1    USD    int 0-1  int 0-3             1.0              1.0
# 1       NaN    BRL        NaN      NaN             2.0              2.0
# 2       NaN    DOP        NaN      NaN             3.0              3.0
# 3       NaN    JMD        NaN      NaN             4.0              4.0
# 4       NaN    MXN        NaN      NaN             5.0              5.0
# 5       NaN    NaN        NaN      NaN             6.0              6.0
# 6       NaN    NaN        NaN      NaN             7.0              7.0
# 7       NaN    NaN        NaN      NaN             8.0              8.0
# 8       NaN    NaN        NaN      NaN             9.0              9.0
# 9       NaN    NaN        NaN      NaN            10.0             10.0
# 10      NaN    NaN        NaN      NaN            11.0             11.0
# 11      NaN    NaN        NaN      NaN            12.0             12.0
# 12      NaN    NaN        NaN      NaN             NaN             13.0
# 13      NaN    NaN        NaN      NaN             NaN             14.0
# 14      NaN    NaN        NaN      NaN             NaN             15.0
#
#     FECHA_TOMA_DIAs FECHA_TOMA_AVANCE LT_TOMA_LLEGADA         FIDELIDAD  \
# 0               1.0         Calculado       Calculado           Ninguna
# 1               2.0               NaN             NaN  PalladiumConnect
# 2               3.0               NaN             NaN  PalladiumRewards
# 3               4.0               NaN             NaN    WyndHamRewards
# 4               5.0               NaN             NaN               NaN
# 5               6.0               NaN             NaN               NaN
# 6               7.0               NaN             NaN               NaN
# 7               NaN               NaN             NaN               NaN
# 8               NaN               NaN             NaN               NaN
# 9               NaN               NaN             NaN               NaN
# 10              NaN               NaN             NaN               NaN
# 11              NaN               NaN             NaN               NaN
# 12              NaN               NaN             NaN               NaN
# 13              NaN               NaN             NaN               NaN
# 14              NaN               NaN             NaN               NaN
#
#    COMERCIALIZADORA                 VALOR_USD VALOR_USD_PAX VALOR_USD_NOCHE  \
# 0           int 0-1  Calculado por Metamodelo      Calcular        Calcular
# 1               NaN                       NaN           NaN             NaN
# 2               NaN                       NaN           NaN             NaN
# 3               NaN                       NaN           NaN             NaN
# 4               NaN                       NaN           NaN             NaN
# 5               NaN                       NaN           NaN             NaN
# 6               NaN                       NaN           NaN             NaN
# 7               NaN                       NaN           NaN             NaN
# 8               NaN                       NaN           NaN             NaN
# 9               NaN                       NaN           NaN             NaN
# 10              NaN                       NaN           NaN             NaN
# 11              NaN                       NaN           NaN             NaN
# 12              NaN                       NaN           NaN             NaN
# 13              NaN                       NaN           NaN             NaN
# 14              NaN                       NaN           NaN             NaN
#
#    VALOR_USD_PAX_NOCHE   GRATIS             PAIS                 CONTINENTE  \
# 0             Calcular  int 0-1           ESPANA  Obtenido por df_paises y:
# 1                  NaN      NaN       AFGANISTAN                     AFRICA
# 2                  NaN      NaN          ALBANIA                    AMERICA
# 3                  NaN      NaN         ALEMANIA                  ANTARTIDA
# 4                  NaN      NaN          ANDORRA                       ASIA
# 5                  NaN      NaN           ANGOLA                DESCONOCIDO
# 6                  NaN      NaN         ANGUILLA                    EURESTE
# 7                  NaN      NaN        ANTARTIDA                     EUROPA
# 8                  NaN      NaN  ANTIGUAYBARBUDA                    OCEANIA
# 9                  NaN      NaN      ARABIASAUDI                   ORIENTEM
# 10                 NaN      NaN    ARABIASAUDITA                        NaN
# 11                 NaN      NaN          ARGELIA                        NaN
# 12                 NaN      NaN        ARGENTINA                        NaN
# 13                 NaN      NaN          ARMENIA                        NaN
# 14                 NaN      NaN            ARUBA                        NaN
#
#           SEGMENTO FUENTE_NEGOCIO
# 0              BAR      CORPORATE
# 1    Complimentary    DIRECTSALES
# 2       FixedRates     E-COMMERCE
# 3     GroupLeisure         OTHERS
# 4          Loyalty      T,O,/T,A,
# 5             MICE            NaN
# 6    Miscellaneous            NaN
# 7           Opaque            NaN
# 8          Package            NaN
# 9   TravelIndustry            NaN
# 10        Weddings            NaN
# 11             NaN            NaN
# 12             NaN            NaN
# 13             NaN            NaN
# 14             NaN            NaN

# %%
df_dropdown['HOTEL'].dropna().to_list()
# Out:
# ['ComplejoCostaMujeres',
#  'ComplejoPuntaCana',
#  'ComplejoRivieraMaya',
#  'DominicanFiestaHotel&Casino',
#  'GrandPalladiumImbassaiResort&Spa',
#  'GrandPalladiumJamaica&LadyHamiltonResort',
#  'PalladiumVallarta',
#  'TRSCapCana']
